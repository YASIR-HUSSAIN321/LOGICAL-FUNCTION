# %% [markdown]
# #LOGICAL FUCTION

# %% [markdown]
#
# 1.Write a formula to check if the marks in cell are greater than or equal to 40. If yes, return , otherwise
# .
# B2 "Pass"
# "FaIL
# -  =IF(B2>=40,"PASS","FAIL")
#      EXPLAINTION:
#      -> B2>=40 check wheather the marks are 40 or more
#      ->.if TRUE ->RETURN 'pass"
#      -> if FALSE ->return "FAIL"
# 2.  A company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not
#  - TO check whether an employee gets a bonus ,both condition must condition must be true:
#   .SALES is in cell B2
#   .attendence>90%
#   FORMULA
#   Sales is in B2
#   .Attendance is in cell C2
#   . =IF(AND(B2>400000,C2.=90),BONUS","NO BONUS")
#   3.Write a nested IF formula:
# If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "FaIL
#   -Here is the nested IF Formula based on the given condition
#   (assuming marks are in cell B2)
#
# =IF(B2>=90,"A",IF(B2>=75,"b",IF(B2>=50,"c","FAIL")))
#  4.Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#  .Formula used (VLOOKUP)
#   . EMPID iscolumn A
#   .DEPARMENT IS IN COLUMN C
#    .Data rage  A2;C2
#    =VLOOKUP("E103"<A2:C5,3,FALSE)
